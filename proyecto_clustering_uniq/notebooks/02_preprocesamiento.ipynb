# %% [markdown]
# # Limpieza del conjunto de datos

# %% [markdown]
# ## Lectura de Datos

# %%
import pandas as pd
# Ruta al archivo CSV en tu Google Drive
csv_file_path = "../data/postulantes_unicos.csv"

# Leer el archivo CSV en un DataFrame, especificando la codificación
postulantes_unicos = pd.read_csv(csv_file_path, delimiter=",")

# Mostrar los primeros registros del DataFrame
postulantes_unicos.head()
# Out:
#      UUID                         ESCUELA  \
# 0  eb33a3                INGENIERÍA CIVIL
# 1  41b65f                INGENIERÍA CIVIL
# 2  60d267  INGENIERÍA AGRONÓMICA TROPICAL
# 3  28acbc         INGENIERÍA DE ALIMENTOS
# 4  38c971                INGENIERÍA CIVIL
#
#                                            MODALIDAD  ANNIO_POSTULACION  \
# 0  PRIMERA OPORTUNIDAD PARA ESTUDIANTES DEL QUINT...               2020
# 1  PRIMERA OPORTUNIDAD PARA ESTUDIANTES DEL QUINT...               2020
# 2  PRIMERA OPORTUNIDAD PARA ESTUDIANTES DEL QUINT...               2020
# 3  PRIMERA OPORTUNIDAD PARA ESTUDIANTES DEL QUINT...               2020
# 4  PRIMERA OPORTUNIDAD PARA ESTUDIANTES DEL QUINT...               2020
#
#    UBIGEO DEPARTAMENTO      PROVINCIA   DISTRITO  UBIGEO_ORIGEN  \
# 0   80901        CUSCO  LA CONVENCIÓN  SANTA ANA          80901
# 1   80901        CUSCO  LA CONVENCIÓN  SANTA ANA          80901
# 2   80901        CUSCO  LA CONVENCIÓN  SANTA ANA          80901
# ...

# %% [markdown]
# ## Seleccion de Caracteristicas

# %% [markdown]
# EN Base al EDA (Analisis exploratorio de los datos que se realizo a continuacion se prentende solo seleccionar algunas caracteristicas)

# %%
postulantes_unicos.columns
# Out:
# Index(['UUID', 'ESCUELA', 'MODALIDAD', 'ANNIO_POSTULACION', 'DEPARTAMENTO',
#        'PROVINCIA', 'DISTRITO', 'DEPARTAMENTO_ORIGEN', 'PROVINCIA_ORIGEN',
#        'DISTRITO_ORIGEN', 'DEPARTAMENTO_IE', 'PROVINCIA_IE', 'DISTRITO_IE',
#        'EDAD', 'SEXO', 'PAGO', 'IDIOMA', 'LEE', 'ESCRIBE', 'HABLA',
#        'TIENE_DISCAPACIDAD', 'TIPO_COMUNIDAD', 'COMUNIDAD'],
#       dtype='object')

# %%
# Eliminar la columna 'Fecha_Corte'
postulantes_unicos = postulantes_unicos.drop(columns=['UBIGEO','UBIGEO_ORIGEN','UBIGEO_IE'])

# Mostrar el conjunto de datos después de eliminar la columna
postulantes_unicos.head()
# Out:
#      UUID                         ESCUELA  \
# 0  eb33a3                INGENIERÍA CIVIL
# 1  41b65f                INGENIERÍA CIVIL
# 2  60d267  INGENIERÍA AGRONÓMICA TROPICAL
# 3  28acbc         INGENIERÍA DE ALIMENTOS
# 4  38c971                INGENIERÍA CIVIL
#
#                                            MODALIDAD  ANNIO_POSTULACION  \
# 0  PRIMERA OPORTUNIDAD PARA ESTUDIANTES DEL QUINT...               2020
# 1  PRIMERA OPORTUNIDAD PARA ESTUDIANTES DEL QUINT...               2020
# 2  PRIMERA OPORTUNIDAD PARA ESTUDIANTES DEL QUINT...               2020
# 3  PRIMERA OPORTUNIDAD PARA ESTUDIANTES DEL QUINT...               2020
# 4  PRIMERA OPORTUNIDAD PARA ESTUDIANTES DEL QUINT...               2020
#
#   DEPARTAMENTO      PROVINCIA   DISTRITO DEPARTAMENTO_ORIGEN PROVINCIA_ORIGEN  \
# 0        CUSCO  LA CONVENCIÓN  SANTA ANA               CUSCO    LA CONVENCIÓN
# 1        CUSCO  LA CONVENCIÓN  SANTA ANA               CUSCO    LA CONVENCIÓN
# ...

# %% [markdown]
# ## Codificacion de las varibles categoricas del conjunto de datos

# %%
# Obtener las variables categóricas del DataFrame
variables_categoricas = postulantes_unicos.select_dtypes(include=['object'])

# Mostrar las variables categóricas
variables_categoricas
# Out:
#         UUID                         ESCUELA  \
# 0     eb33a3                INGENIERÍA CIVIL
# 1     41b65f                INGENIERÍA CIVIL
# 2     60d267  INGENIERÍA AGRONÓMICA TROPICAL
# 3     28acbc         INGENIERÍA DE ALIMENTOS
# 4     38c971                INGENIERÍA CIVIL
# ...      ...                             ...
# 3743  4bd590         INGENIERÍA DE ALIMENTOS
# 3744  713295         INGENIERÍA DE ALIMENTOS
# 3745  858e38         INGENIERÍA DE ALIMENTOS
# 3746  a68990         INGENIERÍA DE ALIMENTOS
# 3747  0f37ac         INGENIERÍA DE ALIMENTOS
#
#                                               MODALIDAD DEPARTAMENTO  \
# 0     PRIMERA OPORTUNIDAD PARA ESTUDIANTES DEL QUINT...        CUSCO
# 1     PRIMERA OPORTUNIDAD PARA ESTUDIANTES DEL QUINT...        CUSCO
# 2     PRIMERA OPORTUNIDAD PARA ESTUDIANTES DEL QUINT...        CUSCO
# 3     PRIMERA OPORTUNIDAD PARA ESTUDIANTES DEL QUINT...        CUSCO
# 4     PRIMERA OPORTUNIDAD PARA ESTUDIANTES DEL QUINT...        CUSCO
# ...

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from category_encoders import CountEncoder

# Lista de columnas con variables categóricas y de interés
categorical_cols = [
    "DEPARTAMENTO",
    "PROVINCIA",
    "DISTRITO",
    "DEPARTAMENTO_ORIGEN",
    "PROVINCIA_ORIGEN",
    "DISTRITO_ORIGEN",
    "DEPARTAMENTO_IE",
    "PROVINCIA_IE",
    "DISTRITO_IE",
    "SEXO",
    "LEE",
    "ESCRIBE",
    "HABLA",
    "TIENE_DISCAPACIDAD",
    "TIPO_COMUNIDAD",
    "COMUNIDAD",
]

# Crear un nuevo DataFrame para las variables codificadas
encoded_data = postulantes_unicos.copy()

# Inicializar el LabelEncoder
label_encoder = LabelEncoder()

# Aplicar Label-Encoding a todas las variables categoricas 
# y Count-Encoding a las demás
for col in categorical_cols:
    unique_values = postulantes_unicos[col].nunique()
    if unique_values == 2:
        encoded_data[col] = label_encoder.fit_transform(postulantes_unicos[col])
    else:
        encoded_data[col] = count_encoder.fit_transform(postulantes_unicos[col])
